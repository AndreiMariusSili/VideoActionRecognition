# %%
import os; os.chdir('/Users/Play/Code/AI/master-thesis/src')
from typing import List, Any, Optional
from fastai import vision as vs
from fastai import torch_core
from fastai import core
import numpy as np
import torch
import glob

import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.lines import Line2D
from matplotlib import rc
from IPython.display import HTML
from pipeline import video

import constants as ct

# %%
dataset = (video.VideoList
           .from_folder(ct.SMTH_PREPRO_DATA, extensions=['jpeg'], cut=1, meta=ct.SMTH_LABELS_MERGED)
           .split_by_folder()
           .label_from_folder()
           .databunch(collate_fn=video.collate, num_workers=0, bs=4, no_check=True))

# %%
dataset.show_batch()
